# %%
#Mr Perfect Model(odia,hindi,english)
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
import speech_recognition as sr
from enum import Enum

# %%
data = pd.read_csv("nitya.csv",encoding='iso-8859-1')
data
# Out:
#                                                  Text Language
# 0   Mu? bh?buchi je internet purbaru jete ?krama?a...     Odia
# 1    i do think the internetâs under much greate...  English
# 2   Mujhe lagta hai ki internet par pehle se kahin...    Hindi
# 3   Nenu bhavistunnanu internet pai ippati daka un...   Telugu
# 4   Enna vaazhdhal thonudhal internet-ukku ippodhu...    Tamil
# ..                                                ...      ...
# 56  Eka keycard lock eka samatala card sahita kaam...     Odia
# 57  March masare eka production aircraft ra order ...     Odia
# 58  an order for  production aircraft designated o...  English
# 59  an order for  production aircraft designated o...  English
# 60  March masare oj- designated production aircraf...     Odia
#
# [61 rows x 2 columns]

# %%
print(data.head())
print(data.isnull().sum())
print(data['Language'].value_counts())
print(data.dtypes)
# Out:
#                                                 Text Language
# 0  Mu? bh?buchi je internet purbaru jete ?krama?a...     Odia
# 1   i do think the internetâs under much greate...  English
# 2  Mujhe lagta hai ki internet par pehle se kahin...    Hindi
# 3  Nenu bhavistunnanu internet pai ippati daka un...   Telugu
# 4  Enna vaazhdhal thonudhal internet-ukku ippodhu...    Tamil
# Text        0
# Language    0
# dtype: int64
# Language
# Odia        11
# English      9
# Chinese      9
# Hindi        8
# Telugu       8
# Tamil        8
# Japanese     8
# Name: count, dtype: int64
# Text        object
# Language    object
# dtype: object

# %%
x = np.array(data['Text'])
y = np.array(data['Language'])

# %%
print("Features (Text):", x)
print("Labels (Language):", y)
# Out:
# Features (Text): ['Mu? bh?buchi je internet purbaru jete ?krama?a hoithil? t?h?ru ebe adhika ?krama?a sahita sammukh?na heuchhi. Sarak?r?m?ne ebe internet samparkare bhaya p?inchaanti k?ra?a madhya p?rburu madhya p?rb paschima ?ba? sem?ne eh? sahita samparkita thib? de?agudi ku dekhi?hile, te?u sem?ne bipar?ta manobh?ba prak??a karithile. Sem?ne byabas?yika sw?dh?nat?re sangr?ma karuchhanti y?h? sem?nankara sw?dh?nat?re pratibandhaka ?nith?e kintu sem?ne atyadhika ch??ithile ? sem?ne SOPA saha t?lima neithile.'
#  ' i do think the internetâ\x80\x99s under much greater attack than it has been in the past governments are now afraid of the internet because of the middle east stuff and so theyâ\x80\x99re a little more willing to listen to what i see as a lot of commercial interests that just want to make money by restricting peopleâ\x80\x99s freedoms but theyâ\x80\x99ve also seen a tremendous user reaction like the backlash against sopa i think that governments fight usersâ\x80\x99 freedoms at their own peril'
#  'Mujhe lagta hai ki internet par pehle se kahin zyada hamle ho rahe hain. Sarkarein ab internet se darti hain kyunki madhya purv ke kaaran unhone ise lekar apni chintayein badha di hain, aur ve ab un vyavsayik hiton ko sunne ke liye thoda adhik tayar hain jo logon ki svatantrataon ko seemit karke paisa kamaana chahte hain, lekin unhone upayogkartao ki pratikriya ko bhi dekha hai, jaise SOPA ke khilaf backlash. Mujhe lagta hai ki sarkarein agar upayogkartao ki svatantrataon se takraati hain, to ve khud hi khatre mein pad sakti hain.'
#  'Aberllefenni ennum oru gramam Gwynedd, Wales in thekku pagudhi-il ullathu. Idhu varalartriya Merionethshire/Sir Feirionnydd maavattathilum Afon Dulas pallathakku-ilum irukkirathu.'
#  'Aberllefenni shì wèil? yú Gwynedd, Wales nánbù de y? gè c?nzhu?ng. T? zuòluò yú lìsh? sh?ng Merionethshire/Sir Feirionnydd, bìng wèiyú Afon Dulas xiág? zh?ng.'
#  ' Aberllefenni wa Gwynedd, Wales no minami ni aru mura desu. Sore wa rekishiteki na Merionethshire/Sir Feirionnydd ni zaisuru, Afon Dulas tani ni ichi shiteimasu.'
#  "Eka keycard lock eka samatala card sahita kaam kare, jaha credit card kimba American ebam European driver's license ra saman aakara re thae. Dwara kholiba pain, eka jane byakti ku safalata saha keycard madhyare thiba signature saha milaiba darkara."
#  "March masare eka production aircraft ra order deya ga'? thila jaha ku oj- bibh?ga kar?'igala, ebam du'iti ?ra order ?g??i m?? re deya g?l?, jaha re nau?i aircraft samil thil?, ebam ekati ?r? aircraft ?is?mbara m??are deya g?l? reserve unit ra upay?ga pa'?."
#  'an order for  production aircraft designated oj- was placed in march  and two more orders followed one in may  for nine aircraft and a further  aircraft in december  for use by reserve units'
#  'an order for  production aircraft designated oj- was placed in march  and two more orders followed one in may  for nine aircraft and a further  aircraft in december  for use by reserve units'
#  "March masare oj- designated production aircraft ra order deya ja'ithila, ebam du'iti ?ru order ?g??i m??a re deya ja'ithila, jaah? re nau?i aircraft samil thil?, ebam ?ka ?ru aircraft ?is?mbara m??are reserve unit ra upay?ga pa'? deya ja'ithila."]
# Labels (Language): ['Odia' 'English' 'Hindi' 'Telugu' 'Tamil' 'Chinese' 'Japanese' 'English'
#  'Odia' 'Hindi' 'Telugu' 'Tamil' 'Chinese' 'Japanese' 'Odia' 'Hindi'
#  'Telugu' 'Tamil' 'Chinese' 'Japanese' 'English' 'Odia' 'Hindi' 'Telugu'
#  'Tamil' 'Chinese' 'Japanese' 'English' 'Odia' 'Hindi' 'Telugu' 'Tamil'
#  'Chinese' 'Japanese' 'English' 'Odia' 'Hindi' 'Telugu' 'Tamil' 'Chinese'
#  'Japanese' 'English' 'Odia' 'Hindi' 'Telugu' 'Tamil' 'Chinese' 'Japanese'
#  'Chinese' 'English' 'Odia' 'Hindi' 'Telugu' 'Tamil' 'Chinese' 'Japanese'
#  'Odia' 'Odia' 'English' 'English' 'Odia']

# %%
cv = CountVectorizer()
X = cv.fit_transform(x)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
print("Training Data (Vectorized):", X_train)
# Out:
# Training Data (Vectorized): <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 1141 stored elements and shape (40, 996)>
#   Coords	Values
#   (0, 160)	2
#   (0, 121)	2
#   (0, 875)	3
#   (0, 937)	5
#   (0, 234)	1
#   (0, 567)	3
#   (0, 573)	6
#   (0, 406)	1
#   (0, 620)	1
#   (0, 32)	1
#   (0, 601)	1
#   (0, 874)	1
#   (0, 33)	2
#   (0, 686)	1
#   (0, 348)	3
#   (0, 701)	3
#   (0, 788)	2
#   (0, 812)	1
#   (0, 28)	1
#   (0, 335)	1
#   (0, 473)	1
#   (0, 787)	1
#   (0, 55)	2
#   (0, 333)	1
#   (0, 250)	1
#   :	:
#   (38, 985)	1
#   (38, 245)	1
#   (39, 312)	1
#   (39, 606)	1
#   (39, 28)	1
#   (39, 537)	1
#   (39, 844)	1
#   (39, 138)	1
#   (39, 588)	1
#   (39, 143)	1
#   (39, 115)	1
#   (39, 212)	1
#   (39, 78)	1
#   (39, 145)	1
#   (39, 120)	1
#   (39, 217)	1
#   (39, 65)	1
#   (39, 486)	1
#   (39, 346)	1
#   (39, 309)	2
#   (39, 645)	1
#   (39, 63)	1
#   (39, 615)	1
#   (39, 327)	1
#   (39, 331)	1

# %%
model = MultinomialNB()
model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
accuracy = model.score(X_test, y_test)
print(f"Model Accuracy: {accuracy:.2f}")
# Out:
# Model Accuracy: 0.62

# %%
class Language(Enum):
    ENGLISH = 'en-US'
    FRENCH = 'fr-FR'
    GERMAN = 'de-DE'
    ITALIAN = 'it-IT'
    SPANISH = 'es-ES'
    PORTUGUESE = 'pt-BR'
    KOREAN = "ko-KR"
    CHINESE_SIMPLIFIED = "zh-CN"
    CHINESE_TRADITIONAL = "zh-TW"
    JAPANESE = "ja-JP"
    RUSSIAN = "ru-RU"
    POLISH = "pl-PL"
    UKRAINIAN = "uk-UA"
    BULGARIAN = "bg-BG"
    BENGALI = "bn-BD"
    TURKISH = "tr-TR"
    ARABIC = "ar-SA"
    INDONESIAN = "id-ID"
    THAI = "th-TH"
    VIETNAMESE = "vi-VN"
    MALAY = "ms-MY"
    HINDI = "hi-IN"
    PUNJABI = "pa-IN"
    TELUGU = "te-IN"
    GUJARATI = "gu-IN"
    ORIYA = "or-IN"
    MARATHI = "mr-IN"
    SINDHI = "sd-IN"
    TAMIL = "ta-IN"
    KANNADA = "kn-IN"
    MALAYALAM = "ml-IN"
    ASSAMESE = "as-IN"
    ODIA = "or-IN"
    SANSKRIT = "sa-IN"

# %%
class SpeechToText:
    @staticmethod
    def speech_to_text(device_index=1, language=Language.ENGLISH):
        r = sr.Recognizer()
        with sr.Microphone(device_index=device_index) as source:
            print("Recording...")
            audio = r.listen(source)
            print("Recording Complete...")

            try:
                # Transcribe audio to text
                text = r.recognize_google(audio, language=language.value)
                print(f"Transcribed Text ({language.name}):", text)
                return text
            except sr.UnknownValueError:
                print("Could not understand audio")
                return None
            except sr.RequestError as e:
                print("Request error from Google Speech Recognition service; {0}".format(e))
                return None

# %%
def predict_language_from_audio(device_index=1, language=Language.ENGLISH):
    transcribed_text = SpeechToText.speech_to_text(device_index, language)
    
    if transcribed_text:
        data = cv.transform([transcribed_text]).toarray()
        output = model.predict(data)
        print("Predicted Language:", output)

# %%
if __name__ == "__main__":
    device_index = 1  # Set device index based on available microphones
    language = Language.ENGLISH  # Set language to English for recognition
    predict_language_from_audio(device_index=device_index, language=language)
# Out:
# Recording...
# Recording Complete...
# Transcribed Text (ENGLISH): Ghunghat wala Pila
# Predicted Language: ['Odia']
